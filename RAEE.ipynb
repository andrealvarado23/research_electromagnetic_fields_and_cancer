# %% [markdown]
# <a href="https://colab.research.google.com/github/andrealvarado23/research_electromagnetic_fields_and_cancer/blob/main/RAEE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/ESTADISTICA- RESULTADOS.xlsx")

# %%
df
# Out:
#                                           Unnamed: 0                   AEE  \
# 0                                          CATEGORÍA  RADIOLOGÍA (rayos X)
# 1  Residuos en la categoría de aparatos médicos y...                     3
# 2  Residuos en la categoría de los equipos de inf...                     2
# 3  Residuos en la categoría aparatos electrónicos...                     0
# 4  Residuos en la categoría de aparatos electróni...                     0
#
#                   AEE.1          AEE.2         AEE.3         AEE.4  \
# 0  LABORATORIO CLÍNICO   DERMATOLOGÍA   ODONTOLOGÍA   CARDIOLOGÍA
# 1                     7              2             5             1
# 2                     3              2             2             2
# 3                     3              0             0             0
# 4                     3              0             1             0
#
#                AEE.5          AEE.6            AEE.7                 AEE.8  \
# ...
